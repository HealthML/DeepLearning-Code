# %% [markdown]
#  The table below provides exemplary house prices $y$ in thousands of euros and the corresponding living space in square meters $x$.
#
# | Square meter | 71  | 98  | 128 | 86  | 173 | 83  | 165 | 71  | 116 | 60  |
# |--------------|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|
# | House price (€k)  | 250 | 209 | 349 | 250 | 419 | 225 | 549 | 240 | 340 | 180 |
#
# Propose a linear regression model to predict house prices based on square meter area. Find the parameters of the model using an analytical solution and stochastic gradient descent.
